# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Денис, привет!</b>
#
# Меня зовут Евгений Дащенко, и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Критическая ошибка: ❌</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Хорошо, но можно и лучше: ❗️</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Все отлично: ✅</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-информации" data-toc-modified-id="Загрузка-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка информации</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропущенные-значения" data-toc-modified-id="Пропущенные-значения-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Пропущенные значения</a></span><ul class="toc-item"><li><span><a href="#Атрибут-ceiling_height----высота-потолка" data-toc-modified-id="Атрибут-ceiling_height----высота-потолка-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Атрибут <em>ceiling_height</em> -  высота потолка</a></span></li><li><span><a href="#Атрибут-floors_total---количество-этажей-в-доме" data-toc-modified-id="Атрибут-floors_total---количество-этажей-в-доме-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Атрибут <em>floors_total</em> - количество этажей в доме</a></span></li><li><span><a href="#Атрибут-living_area---жилая-площадь-квартиры" data-toc-modified-id="Атрибут-living_area---жилая-площадь-квартиры-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Атрибут <em>living_area</em> - жилая площадь квартиры</a></span></li><li><span><a href="#Атрибут-is_apartment---апартаменты" data-toc-modified-id="Атрибут-is_apartment---апартаменты-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Атрибут <em>is_apartment</em> - апартаменты</a></span></li><li><span><a href="#Атрибут-kitchen_area---площадь-кухни" data-toc-modified-id="Атрибут-kitchen_area---площадь-кухни-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Атрибут <em>kitchen_area</em> - площадь кухни</a></span></li><li><span><a href="#Атрибут-balcony---число-балконов" data-toc-modified-id="Атрибут-balcony---число-балконов-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Атрибут <em>balcony</em> - число балконов</a></span></li><li><span><a href="#Атрибут-locality_name---населенный-пункт" data-toc-modified-id="Атрибут-locality_name---населенный-пункт-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Атрибут <em>locality_name</em> - населенный пункт</a></span></li><li><span><a href="#Атрибуты-airports_nearest-и-city_center_dist---расстояния-до-аэропорта-и-центра-города" data-toc-modified-id="Атрибуты-airports_nearest-и-city_center_dist---расстояния-до-аэропорта-и-центра-города-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>Атрибуты <em>airports_nearest</em> и <em>city_center_dist</em> - расстояния до аэропорта и центра города</a></span></li><li><span><a href="#Атрибуты-parks_around_3k,-parks_nearest,-ponds_around_3k-и-ponds_nearest" data-toc-modified-id="Атрибуты-parks_around_3k,-parks_nearest,-ponds_around_3k-и-ponds_nearest-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>Атрибуты <em>parks_around_3k</em>, <em>parks_nearest</em>, <em>ponds_around_3k</em> и <em>ponds_nearest</em></a></span></li><li><span><a href="#Атрибут-days_exposition---время-размещения-объявления" data-toc-modified-id="Атрибут-days_exposition---время-размещения-объявления-2.1.10"><span class="toc-item-num">2.1.10&nbsp;&nbsp;</span>Атрибут <em>days_exposition</em> - время размещения объявления</a></span></li></ul></li><li><span><a href="#Преобразование-типов-данных" data-toc-modified-id="Преобразование-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Преобразование типов данных</a></span><ul class="toc-item"><li><span><a href="#Атрибут-first_day_exposition---дата-публикации" data-toc-modified-id="Атрибут-first_day_exposition---дата-публикации-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Атрибут <em>first_day_exposition</em> - дата публикации</a></span></li></ul></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#Атрибут-last_price---последняя-стоимость-жилья" data-toc-modified-id="Атрибут-last_price---последняя-стоимость-жилья-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Атрибут <em>last_price</em> - последняя стоимость жилья</a></span></li><li><span><a href="#Атрибут-total_area---общая-площадь-в-м²" data-toc-modified-id="Атрибут-total_area---общая-площадь-в-м²-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Атрибут <em>total_area</em> - общая площадь в м²</a></span></li><li><span><a href="#Атрибут-rooms---количество-комнат" data-toc-modified-id="Атрибут-rooms---количество-комнат-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Атрибут <em>rooms</em> - количество комнат</a></span></li><li><span><a href="#Атрибут-ceiling_height---высота-потолка" data-toc-modified-id="Атрибут-ceiling_height---высота-потолка-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Атрибут <em>ceiling_height</em> - высота потолка</a></span></li><li><span><a href="#Атрибут-floors_total---количество-этажей-в-доме" data-toc-modified-id="Атрибут-floors_total---количество-этажей-в-доме-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Атрибут <em>floors_total</em> - количество этажей в доме</a></span></li><li><span><a href="#Атрибут-living_area---жилая-площадь-квартиры" data-toc-modified-id="Атрибут-living_area---жилая-площадь-квартиры-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>Атрибут <em>living_area</em> - жилая площадь квартиры</a></span></li><li><span><a href="#Атрибут-floor---этаж" data-toc-modified-id="Атрибут-floor---этаж-2.4.7"><span class="toc-item-num">2.4.7&nbsp;&nbsp;</span>Атрибут <em>floor</em> - этаж</a></span></li><li><span><a href="#Атрибуты-studio-и-open_plan---студия-и-свободная-планировка" data-toc-modified-id="Атрибуты-studio-и-open_plan---студия-и-свободная-планировка-2.4.8"><span class="toc-item-num">2.4.8&nbsp;&nbsp;</span>Атрибуты <em>studio</em> и <em>open_plan</em> - студия и свободная планировка</a></span></li><li><span><a href="#Атрибут-kitchen_area---площадь-кухни" data-toc-modified-id="Атрибут-kitchen_area---площадь-кухни-2.4.9"><span class="toc-item-num">2.4.9&nbsp;&nbsp;</span>Атрибут <em>kitchen_area</em> - площадь кухни</a></span></li><li><span><a href="#Атрибут-balcony---число-балконов" data-toc-modified-id="Атрибут-balcony---число-балконов-2.4.10"><span class="toc-item-num">2.4.10&nbsp;&nbsp;</span>Атрибут <em>balcony</em> - число балконов</a></span></li><li><span><a href="#Атрибуты-airports_nearest,-city_center_dist,-parks_nearest-и-ponds_nearest" data-toc-modified-id="Атрибуты-airports_nearest,-city_center_dist,-parks_nearest-и-ponds_nearest-2.4.11"><span class="toc-item-num">2.4.11&nbsp;&nbsp;</span>Атрибуты <em>airports_nearest</em>, <em>city_center_dist</em>, <em>parks_nearest</em> и <em>ponds_nearest</em></a></span></li></ul></li><li><span><a href="#Предобработка.-Вывод" data-toc-modified-id="Предобработка.-Вывод-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Предобработка. Вывод</a></span></li></ul></li><li><span><a href="#Дополнительные-данные" data-toc-modified-id="Дополнительные-данные-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Дополнительные данные</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#Разнесение-даты-публикации-объявления" data-toc-modified-id="Разнесение-даты-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Разнесение даты публикации объявления</a></span></li><li><span><a href="#Тип-этажа-квартиры" data-toc-modified-id="Тип-этажа-квартиры-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Тип этажа квартиры</a></span></li><li><span><a href="#Расстояние-до-центра-города-в-километрах" data-toc-modified-id="Расстояние-до-центра-города-в-километрах-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Расстояние до центра города в километрах</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Анализ-значимых-параметров" data-toc-modified-id="Анализ-значимых-параметров-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ значимых параметров</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь,-жилая-площадь-и-площадь-кухни" data-toc-modified-id="Общая-площадь,-жилая-площадь-и-площадь-кухни-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Общая площадь, жилая площадь и площадь кухни</a></span></li><li><span><a href="#Цена-объекта" data-toc-modified-id="Цена-объекта-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена объекта</a></span></li><li><span><a href="#Количество-комнат-и-высота-потолков" data-toc-modified-id="Количество-комнат-и-высота-потолков-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Количество комнат и высота потолков</a></span></li><li><span><a href="#Этажи" data-toc-modified-id="Этажи-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Этажи</a></span></li><li><span><a href="#Расстояния-до-центра-СПб,-аэропорта-и-ближайшего-парка" data-toc-modified-id="Расстояния-до-центра-СПб,-аэропорта-и-ближайшего-парка-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Расстояния до центра СПб, аэропорта и ближайшего парка</a></span></li><li><span><a href="#Время-публикации-объявления" data-toc-modified-id="Время-публикации-объявления-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Время публикации объявления</a></span></li></ul></li><li><span><a href="#Анализ-скорости-продажи-квартир" data-toc-modified-id="Анализ-скорости-продажи-квартир-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ скорости продажи квартир</a></span></li><li><span><a href="#Оценка-влияния-на-стоимость-квартиры" data-toc-modified-id="Оценка-влияния-на-стоимость-квартиры-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Оценка влияния на стоимость квартиры</a></span></li><li><span><a href="#Оценка-средней-цены-по-городам" data-toc-modified-id="Оценка-средней-цены-по-городам-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Оценка средней цены по городам</a></span></li><li><span><a href="#Оценка-стоимости-по-расположению-квартиры" data-toc-modified-id="Оценка-стоимости-по-расположению-квартиры-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Оценка стоимости по расположению квартиры</a></span></li><li><span><a href="#История-стоимости-на-квартиры-в-Санкт-Петербурге" data-toc-modified-id="История-стоимости-на-квартиры-в-Санкт-Петербурге-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>История стоимости на квартиры в Санкт-Петербурге</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Исследовательский анализ недвижимости Ленинградской области

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# <s>Рекомендуется делать краткое вступление в работу и описание того, что планируешь сделать (если план у тебя уже сформирован), а также информацию о входных данных: какие столбцы есть в таблице, их названия и какую информацию они несут. Так работа станет выглядеть презентабельнее.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Привет! Приятно познакомиться.
# Добавил вступление</div>

# %% [markdown]
# В качестве данных для анализа Отделом Данных был предоставлен датасет архива сервиса Яндекс Недвижимость за несколько лет. Нашей **задачей** является:
# - предобработка данных: найти пропуски в данных, дубликаты и аномальные значения
# - провести исследовательский анализ: изучить параметры объектов; скорость продажи; факторы, влияющие на стоимость; стоимость в зависимости от населенного пункта
# - сделать общий вывод
#
# ***
# Исходные данные имеют следующую структуру:
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — общая площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ## Загрузка информации

# %% [markdown]
# **Загрузим используемые библиотеки, а также файл с данными**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Уберем ограничение на отображение таблиц в ширину
pd.set_option('display.max_columns', None)
# Установим формат вывода чисел с плавающей точкой в pandas
pd.set_option('display.float_format', lambda x: '%.5f' % x)

try:
    data = pd.read_csv('real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# Создадим датафрейм с копией исходных данных для возможности сравнения в будущем

# %%
raw_data = data.copy()

# %% [markdown]
# Изучим общую информацию о таблице

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Имеем таблицу, состоящую из 23699 записей. В таблице 22 колонки со следующими типами:
# - `bool` - 2 шт.
# - `int` - 3 шт.
# - `object` - 3 шт.
# - `float` - 14 шт.
#
# Приведем имена столбцов к единому стилю

# %%
data = data.rename(columns={'cityCenters_nearest': 'city_center_dist',
                            'parks_around3000': 'parks_around_3k',
                            'ponds_around3000': 'ponds_around_3k'})

# %% [markdown]
# Построим гистограммы для каждого числового атрибута:

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# *Краткий вывод:* точно стоит обратить внимание на `last_price` - это один из самых важных атрибутов. При этом гистограмма не имеет вид нормального или пуассоновского распределения. Также нужно обратить вниамени на `total_area`, `ceiling_height`, `living_area` и `kitchen_area` - наверняка есть выбросы в данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Классный способ визуализировать распределения сразу для всех столбцов 👍
#
# </div>

# %% [markdown]
# **Построим матрицу корреляции по всей таблице данных**

# %%
data.corr()
# Out:
# C:\Users\denis\AppData\Local\Temp/ipykernel_12040/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   total_images  last_price  total_area    rooms  \
# total_images           1.00000     0.10447     0.11535  0.09929
# last_price             0.10447     1.00000     0.65368  0.36334
# total_area             0.11535     0.65368     1.00000  0.75834
# rooms                  0.09929     0.36334     0.75834  1.00000
# ceiling_height        -0.00199     0.08543     0.09549  0.05446
# floors_total           0.01043    -0.00698    -0.07577 -0.22822
# living_area            0.10478     0.56649     0.93954  0.84598
# floor                  0.03134     0.02658    -0.02475 -0.15086
# studio                -0.02930    -0.02536    -0.07265 -0.14729
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# <s>Тут, что-то сломалось.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Ошибку исправил. Но немного поною. Я согласен с тем, что было оговорено, что я должен сдавать проекты на той версии библиотек, которые входят в выдаваемую среду. Этот момент я не проверил. Но камон - 1.2.4?? Этот пакет pandas вышел полтора года назад - в апреле 2021. Без параметра numeric_only выходит предупреждение. Чтобы от него избавиться нужно перечислить все числовые атрибуты датасета.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Дело в том, что есть приложения / проекты которые работают на определенных версиях библиотек и их обновление может привести к поломкам. Поэтому и существует рекомендация по установке определенных версий библиотек 😊
#
# В целом это распространенная практика от проекта к проекту, и срок реализации библиотеки на это не влияет 😊
#
# </div>

# %% [markdown]
# *Краткий вывод:* кажется очевидным, что стоимость сильно зависит от общей площади и расстояния до центра. Первое предположение подтверждается, второе же нужно проверить. Матрица корреляции говорит об обратном, но нужно сначала проверить что хранится в `city_center_dist`.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропущенные значения

# %% [markdown]
# **Найдем столбцы с пустыми значениями**

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_center_dist         5519
# parks_around_3k          5518
# parks_nearest           15620
# ponds_around_3k          5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Видим, что пустые значения есть в следующих столбцах:
# - `ceiling_height`
# - `floors_total`
# - `living_area`
# - `is_apartment`
# - `kitchen_area`
# - `balcony`
# - `locality_name`
# - `airports_nearest`
# - `city_center_dist`
# - `parks_around_3k`
# - `parks_nearest`
# - `ponds_around_3k`
# - `ponds_nearest`
# - `days_exposition`

# %% [markdown]
# **Обработаем пропуски в исходных данных**

# %% [markdown]
# #### Атрибут *ceiling_height* -  высота потолка

# %% [markdown]
# Из матрицы корреляции видно, что значение высоты потолков не связано ни с одним другим параметром квартиры. Значение корреляции по всем параметрам меньше 10%. Можно было бы предположить, что высота потолков может быть связана с годом постройки дома, но эта информация не была предоставлена.
# Исходя из этого заполним пропуски медианным значением.

# %%
sns.histplot(data=data['ceiling_height'], bins=10, binrange=(2.4, 4));
plt.title('Высота потолков')
plt.show;

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера: ❗️</b>
#
# Не забывай пожалуйста подписывать каждый график. Это важный момент всего проекта, так мы быстрее сможем понять о чем идёт речь на самом графике.
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Поменял на seaborn</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Это супер 👍, но я говорил о подписях для графиков 😊
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Готово</div>

# %%
ceiling_median = round(data['ceiling_height'].median(), 2)
data['ceiling_height'] = data['ceiling_height'].fillna(ceiling_median)
print(f'Медианная высота потолков: {ceiling_median} м.')
# Out:
# Медианная высота потолков: 2.65 м.

# %%
sns.histplot(data=data['ceiling_height'], bins=10, binrange=(2.4, 4));
plt.title('Высота потолков после преобразования')
plt.show;

# %% [markdown]
# *Вывод:* произвели замену пропусков на медианное значение. Распределение приняло вид распределения Пуассона.

# %% [markdown]
# #### Атрибут *floors_total* - количество этажей в доме

# %% [markdown]
# **Построим гистаграмму и изучим данные**

# %%
(sns
 .histplot(data=data['floors_total'],
           bins=10)
 .set(title='Распределение количества этажей в доме')
);

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати для того чтобы подписать график мы можем использовать метод `plt.title()` и в конце кода применить `plt.show()`
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Нашел еще метод .set(title='')</div>

# %% [markdown]
# В Петербурге бóльшая часть жилого фонда - малоэтажные дома. Учитывая, что данные включают область, где высоток еще меньше, можно предположить, что гистограмма похожа на правду.

# %%
print(f'Медианное количество этажей в доме: {int(data["floors_total"].mean())} эт.')
# Out:
# Медианное количество этажей в доме: 10 эт.

# %% [markdown]
# Медианное количество этажей - 10. Но если подставить его по всем отсутствующим значениям, то появятся записи с квартирами, находящимися на этажах выше высотности дома.
# Чтобы этого избежать сохраним в переменную `floors_dict` словарь с медианной высотностью в зависимости от этажа квартиры - индекса.

# %%
floors_dict = (data
               .pivot_table(index='floor',
                            values='floors_total',
                            aggfunc='median'
                            )
               .to_dict('dict')  # Преобразуем сводную таблицу в словарь
               .get('floors_total')  # Нужный нам словарь находится в ключе с именем floors_total
               )
floors_dict
# Out:
# {1: 5.0,
#  2: 5.0,
#  3: 5.0,
#  4: 5.0,
#  5: 6.0,
#  6: 9.0,
#  7: 10.0,
#  8: 10.0,
#  9: 10.0,
#  10: 16.0,
#  11: 16.0,
#  12: 16.0,
#  13: 17.0,
#  14: 17.0,
#  15: 17.0,
#  16: 18.0,
#  17: 22.0,
#  18: 22.0,
#  19: 24.0,
#  20: 24.0,
#  21: 25.0,
#  22: 25.0,
#  23: 25.0,
#  24: 25.0,
#  25: 25.0,
#  26: 27.0,
#  27: 27.0,
#  28: 36.0,
#  29: 36.0,
#  30: 35.0,
#  31: 35.0,
#  32: 33.0,
#  33: 35.0}

# %% [markdown]
# **Заполним пустые значения этажности дома**

# %%
data['floors_total'] = data['floors_total'].fillna(data['floor'].map(floors_dict))

# %% [markdown]
# **Убедимся, что все атрибуты заполнились**

# %%
print(f'Незаполненных атрибутов floors_total: {data["floors_total"].isna().sum()}')
# Out:
# Незаполненных атрибутов floors_total: 0

# %% [markdown]
# *Вывод:* атрибут `floors_total` важен для выборки, т.к. есть предположение, что квартиры на первых и последних этажах ложны отличаться по цене от аналогичных квартир на других этажах.  Поэтому мы заменили отсутствующие значения на медианные.

# %% [markdown]
# #### Атрибут *living_area* - жилая площадь квартиры

# %% [markdown]
# Жилая площадь является важной характеристокой квартиры, это можно увидеть по прямой корреляции со стоимостью. Да и интуитивно это тоже понятно.
# Поэтому не будем заполнять эти данные синтетическими значениями, а оставим их пустыми.

# %% [markdown]
# #### Атрибут *is_apartment* - апартаменты

# %% [markdown]
# *Уточнение: апартаменты - особый юридический статус недвижимости. Апартаменты не являются жилым фондом, поэтому на них не распространяется соблюдение условия на наличие социальных объектов: школ, больниц и тд. Подробную информацию можно запросить в юр. отделе. Важно, что такой статус скорее всего влияет на стоимость недвижимости при прочих равных (нужно убедиться).*

# %% [markdown]
# В описание данных написано, что этот атрибут является булевым и определяет является ли данная недвижимость апартаментами. При этом `info` описало атрибут как `object`. Необходимо проанализировать какие значения хранятся в атрибуте.

# %%
# Этот вариант хорошо работает со свежим pandas, оставим его на будущее
# data.value_counts(subset=['is_apartment'], normalize=True, dropna=False).round(2)

(f'В атрибуте is_apartment отсутствуют данные по ' +
 f'{int(data["is_apartment"].isna().sum() / len(data) * 100)}% строк')
# Out:
# 'В атрибуте is_apartment отсутствуют данные по 88% строк'

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# <s>И здесь ☹️
#
# Возвращаю проект обратно, чтобы можно было исправить ошибки и полноценно проверить его.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> А в pandas 1.5 появился параметр dropna. Но можно и без него :)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Честно говоря не знаю этот момент.
#
# </div>

# %% [markdown]
# **Отсутствуют данные по 88% записей. Это много.**

# %% [markdown]
# Анализ по такому количеству невозможен. Необходимо запросить в отделе данных уточнение или удалить столбец.
# **Удаляем столбец**

# %%
data = data.drop(columns='is_apartment')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   studio                23699 non-null  bool
#  10  open_plan             23699 non-null  bool
#  11  kitchen_area          21421 non-null  float64
#  12  balcony               12180 non-null  float64
#  13  locality_name         23650 non-null  object
#  14  airports_nearest      18157 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# А если все остальные значения просто False ?
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Можем поставить False, конечно. Но даст ли нам это качественные данные? В 23к строк всего 50 квартир-апартов. Мне кажется, это не совсем реальное соотношение.</div>

# %% [markdown]
# #### Атрибут *kitchen_area* - площадь кухни

# %% [markdown]
# Здесь аналогичная ситуация с атрибутом `living_area` - синтетические данные не прибавят качества исследованию, поэтому оставим пустые данные без изменений.

# %% [markdown]
# #### Атрибут *balcony* - число балконов

# %% [markdown]
# **Проанализируем данные по атрибуту**

# %%
# Этот вариант хорошо работает со свежим pandas, оставим его на будущее
# data.value_counts(subset=['balcony'], dropna=False).round(2)

(f'В атрибуте balcony отсутствуют данные по ' +
 f'{int(data["balcony"].isna().sum() / len(data) * 100)}% строк')
# Out:
# 'В атрибуте balcony отсутствуют данные по 48% строк'

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Оставил пример ниже, как можно посчитать долю пропущенных значений еще сразу для всех столбцов.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Спасибо. Так действительно проще :)</div>

# %%
data.isna().mean()
# Out:
# total_images           0.00000
# last_price             0.00000
# total_area             0.00000
# first_day_exposition   0.00000
# rooms                  0.00000
# ceiling_height         0.00000
# floors_total           0.00000
# living_area            0.08030
# floor                  0.00000
# studio                 0.00000
# open_plan              0.00000
# kitchen_area           0.09612
# balcony                0.48605
# locality_name          0.00207
# airports_nearest       0.23385
# city_center_dist       0.23288
# parks_around_3k        0.23284
# parks_nearest          0.65910
# ponds_around_3k        0.23284
# ponds_nearest          0.61560
# days_exposition        0.13423
# dtype: float64

# %% [markdown]
# Мы видим, что более чем в 11000 строках не заполнена информация о количестве балконов в объекте недвижимости. Мы можем предположить, что это является признаком отсутствия балкона. В идеале стоит уточнить этот вопрос в отделе, который предоставил данные.

# %% [markdown]
# **Заменим пропущенные значения на 0**

# %%
data['balcony'] = data['balcony'].fillna(0)

# %% [markdown]
# #### Атрибут *locality_name* - населенный пункт

# %% [markdown]
# Населенный пункт не заполнен по 49 записям, посмотрим первые 5:

# %%
data[data['locality_name'].isna()].head()
# Out:
#       total_images    last_price  total_area first_day_exposition  rooms  \
# 1097             3 8600000.00000    81.70000  2016-04-15T00:00:00      3
# 2033             6 5398000.00000    80.00000  2017-05-30T00:00:00      3
# 2603            20 3351765.00000    42.70000  2015-09-20T00:00:00      1
# 2632             2 5130593.00000    62.40000  2015-10-11T00:00:00      2
# 3574            10 4200000.00000    46.50000  2016-05-28T00:00:00      2
#
#       ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 1097         3.55000       5.00000     50.80000      2   False      False
# 2033         2.65000       4.00000     42.60000      2   False      False
# 2603         2.65000      24.00000     15.60000      3   False      False
# 2632         2.65000      24.00000     33.10000     21   False      False
# 3574         2.65000       5.00000     30.80000      5   False      False
#
#       kitchen_area  balcony locality_name  airports_nearest  city_center_dist  \
# ...

# %% [markdown]
# В целом остальные данные заполнены, нет необходимости избавляться от этих объектов.
# **Заменим отсутствующие значения на строку "Неизвестно".**

# %%
data['locality_name'] = data['locality_name'].fillna('Неизвестно')

# %% [markdown]
# *Вывод:* важно понимать в каком населенном пункте распологается объект, поэтому выведем пустые значения в отдельную грппу - Неизвестно.

# %% [markdown]
# #### Атрибуты *airports_nearest* и *city_center_dist* - расстояния до аэропорта и центра города

# %% [markdown]
# Процент пропущенных значений в атрибутах:
# - `airports_nearest`: 23%
# - `city_center_dist`: 23%
#
# Оставим эти данные как есть, но будем помнить о пробеле в данных.

# %% [markdown]
# #### Атрибуты *parks_around_3k*, *parks_nearest*, *ponds_around_3k* и *ponds_nearest*

# %% [markdown]
# Скорее всего атрибуты так же являются вспомогательными. Можно предположить, что продавцы квартир не утруждают себя подсчетом количества парков и расстояния до ближайшего из них, и именно с этим связан большой процент отсутствующих данных: **23%** для `parks_around_3k` и `ponds_around_3k`, **66%** для `parks_nearest` и `ponds_nearest`.

# %% [markdown]
# Атрибуты `parks_around_3k` и `ponds_around_3k` можно заполнить значением **"1"**, если заполнен соответствующий `parks_nearest` и `ponds_nearest` и значение меньше 3000.
# **Проверим есть ли такие записи**

# %%
len(data.query('parks_around_3k != parks_around_3k and parks_nearest < 3000'))
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера (2): ✅</b>
#
# Когда используешь множественную фильтрацию, рекомендую использовать метод `loc`, т.к. он работает быстрее и читается проще.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Ок, учту в будущем</div>

# %% [markdown]
# Таких записей нет, проверим подобным образом `ponds_around_3k`

# %%
len(data.query('ponds_around_3k != ponds_around_3k and ponds_nearest < 3000'))
# Out:
# 0

# %% [markdown]
# Таких записей тоже нет.
#
# **Проверим данные на адекватность заполнения**
# Убедимся, что нет записей с числом парков или водоемов ближе 3 км, и при этом ближайший из них дальше 3 км.

# %%
len(data.query('parks_around_3k > 0 and parks_nearest >= 3000'))
# Out:
# 0

# %%
len(data.query('ponds_around_3k > 0 and ponds_nearest >= 3000'))
# Out:
# 0

# %% [markdown]
# Данные заполнены ответственно.
#
# **Заменим отсутствующие данные в атрибутах** `parks_around_3k` **и** `ponds_around_3k` **на нули.**

# %%
data['parks_around_3k'] = data['parks_around_3k'].fillna(0)
data['ponds_around_3k'] = data['ponds_around_3k'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# В том числе метод `fillna` и `astype` можно применять к нескольким столбцам одновременно.
#
# Если столбцов более 2–ух, то рекомендую применять цикл `for`.
#
# Пример:
#
# `df.astype({ "col1": "float64", "col2": "int64"})`
#
# </div>

# %% [markdown]
# #### Атрибут *days_exposition* - время размещения объявления

# %% [markdown]
# Предположу, что причина отсутствия данных состоит в технических ошибках выгрузки или хранения информации.
# Можно задать этот вопрос в отдел ведения данных.
# **Посмотрим на 10 записей без атрибута**

# %%
data[data['days_exposition'].isna()].head(10)
# Out:
#     total_images     last_price  total_area first_day_exposition  rooms  \
# 0             20 13000000.00000   108.00000  2019-03-07T00:00:00      3
# 7              5  7915000.00000    71.60000  2019-04-18T00:00:00      2
# 44            13  5350000.00000    40.00000  2018-11-18T00:00:00      1
# 45            17  5200000.00000    50.60000  2018-12-02T00:00:00      2
# 46            17  6600000.00000    52.10000  2019-01-31T00:00:00      2
# 49             1  3050000.00000    30.80000  2018-11-22T00:00:00      1
# 52            20 11795000.00000   136.00000  2017-09-22T00:00:00      6
# 71            20  4850000.00000    57.50000  2019-03-27T00:00:00      3
# 81             9 10949000.00000    68.00000  2018-12-27T00:00:00      1
# 84            11  2400000.00000    43.90000  2019-03-13T00:00:00      2
#
#     ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0          2.70000      16.00000     51.00000      8   False      False
# ...

# %% [markdown]
# **Оставим отсутствующие данные как есть**

# %% [markdown]
# ### Преобразование типов данных

# %% [markdown]
# #### Атрибут *first_day_exposition* - дата публикации

# %% [markdown]
# Данный атрибут является датой. В датафрейме он имеет тип `object`, т.е. строка. Следует привести его к формату даты для удобства работы в будущем.
# **Переведем дату в соответствующий формат.**

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],
                                              format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# ### Поиск дубликатов

# %% [markdown]
# **Проверим данные на наличие явных дубликатов**

# %%
print(f'Найдено {data.duplicated().sum()} дубликатов')
# Out:
# Найдено 0 дубликатов

# %% [markdown]
# Явных дубликатов не найдено. Переходим к поиску неявных.
# Неявные дубликаты часто встречаются в текстовых атрибутах. В нашем датасете есть 1 такой атрибут - `locality_name`.
# Причина дубликатов связана с человеческим фактором:
# - пользователь может допустить опечатку
# - использование буквы "ё"
# - несоблюдение регистров при написании
#
# Также причины могут быть техническими:
# - неправильная кодировка текста
# - населенный пункт может со временем изменить тип - например, поселок может стать поселком городского типа

# %% [markdown]
# **Посмотрим на качество заполнения населенных пунктов**

# %%
print(f'Всего нас. пунтов: {len(data["locality_name"].unique())}')
data['locality_name'].unique()
# Out:
# Всего нас. пунтов: 365
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# На глаз сложно найти дубликаты, но сразу можно выделить:
# - буквы "е" и "ё"
# - встречаются населенные пункты с обозначением типа и без
#
# **Создадим новую колонку для обработанного наименования нас. пункта и заменим буквы "ё" на "е"**

# %%
data.insert(loc=14,
            column='locality_clean_name',
            value=data['locality_name'].str.lower().str.replace('ё', 'е')
           )
data.head()
# Out:
#    total_images     last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00000   108.00000           2019-03-07      3
# 1             7  3350000.00000    40.40000           2018-12-04      1
# 2            10  5196000.00000    56.00000           2015-08-20      2
# 3             0 64900000.00000   159.00000           2015-07-24      3
# 4             2 10000000.00000   100.00000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0         2.70000      16.00000     51.00000      8   False      False
# 1         2.65000      11.00000     18.60000      1   False      False
# 2         2.65000       5.00000     34.30000      4   False      False
# 3         2.65000      14.00000          NaN      9   False      False
# 4         3.03000      14.00000     32.00000     13   False      False
#
#    kitchen_area  balcony    locality_name locality_clean_name  \
# ...

# %% [markdown]
# **Изучим оставшиеся записи**

# %%
cities = list(np.sort(data['locality_clean_name'].unique()))
for city in cities:
    print(city)
# Out:
# бокситогорск
# волосово
# волхов
# всеволожск
# выборг
# высоцк
# гатчина
# городской поселок большая ижора
# городской поселок будогощь
# городской поселок виллози
# городской поселок лесогорский
# городской поселок мга
# городской поселок назия
# городской поселок новоселье
# городской поселок павлово
# городской поселок рощино
# городской поселок свирьстрой
# городской поселок советский
# городской поселок федоровское
# городской поселок янино-1
# деревня агалатово
# деревня аро
# деревня батово
# деревня бегуницы
# деревня белогорка
# деревня большая вруда
# деревня большая пустомержа
# деревня большие колпаны
# деревня большое рейзино
# деревня большой сабск
# деревня бор
# деревня борисова грива
# деревня ваганово
# деревня вартемяги
# деревня вахнова кара
# деревня выскатка
# деревня гарболово
# деревня глинка
# деревня горбунки
# деревня гостилицы
# деревня заклинье
# деревня заневка
# деревня зимитицы
# деревня извара
# деревня иссад
# деревня калитино
# деревня кальтино
# ...

# %% [markdown]
# В рамках анализа можно избавиться от типа населенного пункта и оставить только имя собственное.

# %%
data['locality_clean_name'] = (
    data['locality_clean_name']
    .str.replace('городской поселок ', '')
    .str.replace('поселок городского типа ', '')
    .str.replace('поселок при железнодорожной станции ', '')
    .str.replace('поселок станции ', '')
    .str.replace('коттеджный поселок ', '')
    .str.replace('поселок ', '')
    .str.replace('садоводческое некоммерческое товарищество ', '')
    .str.replace('садовое товарищество ', '')
    .str.replace('деревня ', '')
    .str.replace('село ', '')
    .str.title()  # сделаем первые буквы заглавными
    )
data.head(15)
# Out:
#     total_images     last_price  total_area first_day_exposition  rooms  \
# 0             20 13000000.00000   108.00000           2019-03-07      3
# 1              7  3350000.00000    40.40000           2018-12-04      1
# 2             10  5196000.00000    56.00000           2015-08-20      2
# 3              0 64900000.00000   159.00000           2015-07-24      3
# 4              2 10000000.00000   100.00000           2018-06-19      2
# 5             10  2890000.00000    30.40000           2018-09-10      1
# 6              6  3700000.00000    37.30000           2017-11-02      1
# 7              5  7915000.00000    71.60000           2019-04-18      2
# 8             20  2900000.00000    33.16000           2018-05-23      1
# 9             18  5400000.00000    61.00000           2017-02-26      3
# 10             5  5050000.00000    39.60000           2017-11-16      1
# 11             9  3300000.00000    44.00000           2018-08-27      2
# ...

# %%
print(f'Всего нас. пунтов после обработки дубликатов: {len(data["locality_clean_name"].unique())}')
# Out:
# Всего нас. пунтов после обработки дубликатов: 306

# %% [markdown]
# Короткий вывод: мы добавили новый атрибут `locality_clean_name` с очищенными данными по местоположению объекта недвижимости. Количество уникальных населенных пунтков снизилось почти на 20% с 365 до 306.

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Посмотрим еще раз на гистограммы всех атрибутов**

# %%
data.hist(figsize=(15, 20));

# %% [markdown]
# Обработка пустых значений не принесла принципиальных изменений в общих графиках. По-прежнему нужно присмотреться к атрибутам `last_price`, `total_area`, `ceiling_height`, `living_area` и `kitchen_area`. Похоже, что по нима есть аномальные значения.

# %% [markdown]
# #### Атрибут *last_price* - последняя стоимость жилья

# %% [markdown]
# **Построим описание атрибута**

# %%
data['last_price'].describe()
# Out:
# count       23699.00000
# mean      6541548.77155
# std      10887013.26754
# min         12190.00000
# 25%       3400000.00000
# 50%       4650000.00000
# 75%       6800000.00000
# max     763000000.00000
# Name: last_price, dtype: float64

# %% [markdown]
# Среднее значение равно 6.5 млн руб., а дисперсия 10.9 млн. руб. Такое распределение не является распределением Пуассона, которым в теории должно быть. Из описания видно, что данные содержат как очень дешевые квартиры (12 190 руб.), так и очень дорогие (763 000 000 руб.). Рассмотрим выбивающиеся значения внимательнее.

# %% [markdown]
# Цена 12190 руб. не кажется правдоподобной
# **Отсортируем данные по цене и посмотрим первые 10 записей**

# %%
data.sort_values(by='last_price').head(10)
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 8793              7  12190.00000   109.00000           2019-03-20      2
# 17456             7 430000.00000    30.40000           2019-04-22      1
# 14911             5 430000.00000    54.00000           2018-06-26      2
# 16274            18 440000.00000    40.00000           2018-07-10      1
# 17676             0 450000.00000    36.50000           2018-02-01      1
# 16219            14 450000.00000    38.50000           2018-07-11      2
# 9581              7 450000.00000    43.40000           2018-08-31      2
# 5698              7 450000.00000    42.00000           2017-07-31      2
# 21912             0 470000.00000    37.00000           2018-02-18      1
# 18867             1 470000.00000    41.00000           2018-02-11      1
#
#        ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 8793          2.75000      25.00000     32.00000     25   False      False
# ...

# %% [markdown]
# Мы видим, что в данных есть всего 1 запись с подозрительно низкой ценой. Судя по тому, что квартира находится в Санкт-Петербурге и имеет площадь 109 м², можно предположить, что цена указана в тысячах рублей. Но так как это невозможно проверить, то просто удалим эту запись по индексу.

# %%
data = data.drop(index=8793)

# %% [markdown]
# Перейдем к дорогим квартирам.
# **Построим гистограммы стоимости для разных выборок данных.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 4, 4, 4]})
fig.suptitle('Анализ стоимости жилья', fontsize=16)

fig.tight_layout()
sns.boxplot(y=data['last_price'], ax=axes[0])
fig.tight_layout()
sns.histplot(data=data['last_price'], ax=axes[1], bins=30).set(title='Все стоимости');
fig.tight_layout()
(sns
 .histplot(data=data['last_price'], ax=axes[2], bins=30, binrange=(0, 20000000))
 .set(title='Ограничение сверху 20 000 000')
);
fig.tight_layout()
(sns
 .histplot(data=data['last_price'], ax=axes[3], bins=30, binrange=(0, 50000000))
 .set(title='Ограничение сверху 50 000 000')
);

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Здорово, что используешь уже метод `subplots` 👍
#
# </div>

# %%
vip_apart_count_15 = data.query('last_price>15000000')['last_price'].count()
vip_apart_count_20 = data.query('last_price>20000000')['last_price'].count()
vip_apart_count_30 = data.query('last_price>30000000')['last_price'].count()

print(f'Количество квартир дороже 15 млн. руб.: {vip_apart_count_15} шт.'+
      f', это {round(vip_apart_count_15 / len(data) * 100, 2)} %')
print(f'Количество квартир дороже 20 млн. руб.: {vip_apart_count_20} шт.'+
      f', это {round(vip_apart_count_20 / len(data) * 100, 2)} %')
print(f'Количество квартир дороже 30 млн. руб.: {vip_apart_count_30} шт.'+
      f', это {round(vip_apart_count_30 / len(data) * 100, 2)} %')
# Out:
# Количество квартир дороже 15 млн. руб.: 1204 шт., это 5.08 %
# Количество квартир дороже 20 млн. руб.: 707 шт., это 2.98 %
# Количество квартир дороже 30 млн. руб.: 316 шт., это 1.33 %

# %% [markdown]
# Мы видим, что более 97% квартир стоят дешевле 20 000 000 руб. Для анализа *не премиального* рынка будет достаточно ограничиться срезом квартир со стоимостью меньше 20 млн. руб.

# %%
data = data.query('last_price<20000000')
data['last_price'].describe()
# Out:
# count      22975.00000
# mean     5413691.38625
# std      3198086.74896
# min       430000.00000
# 25%      3400000.00000
# 50%      4550000.00000
# 75%      6500000.00000
# max     19999000.00000
# Name: last_price, dtype: float64

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
fig.suptitle('Стоимость жилья после обработки', fontsize=16)

fig.tight_layout()
sns.histplot(data=data['last_price'], ax=axes[0], bins=30);
sns.violinplot(y=data['last_price'], ax=axes[1]);

# %% [markdown]
# *Вывод:* Мы потеряли часть данных, но избавились от выбивающихся хвостов. По факту мы потеряли меньше 3% данных, что не отразитяся на результатах исследования.

# %% [markdown]
# #### Атрибут *total_area* - общая площадь в м²

# %% [markdown]
# Начнем с изучения описания атрибута

# %%
data['total_area'].describe()
# Out:
# count   22975.00000
# mean       56.67603
# std        24.60898
# min        12.00000
# 25%        40.00000
# 50%        51.00000
# 75%        67.00000
# max       320.00000
# Name: total_area, dtype: float64

# %% [markdown]
# **Построим графики**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 3, 3]})
fig.suptitle('Анализ общей площади', fontsize=16)

fig.tight_layout()
sns.boxplot(y=data['total_area'], ax=axes[0])
fig.tight_layout()
sns.histplot(data=data['total_area'], ax=axes[1], bins=30);
fig.tight_layout()
sns.violinplot(y=data['total_area'], ax=axes[2]);

# %% [markdown]
# Гистограмма сильно напоминает гистограмму последней цены. Аномальных значений не наблюдается. На графике-скрипке мы видим не совсем гладкую кривую. Посмотрим этот момент поближе.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Чтобы подписать графики `subplots`, мы можем использовать метод
#
# `fig.suptitle('This is a somewhat long figure title', fontsize=16)`
#
# </div>

# %%
(sns
 .histplot(data=data['total_area'], bins=40, binrange=(0, 150))
 .set(title='Общие площади до 150 м2')
);

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
fig.suptitle('Общая площадь в зависимости от этажа', fontsize=16)

fig.tight_layout()
(sns
 .histplot(data=data[data['floor'] == 1]['total_area'], ax=axes[0], bins=30, binrange=(0,100))
 .set(title='Общая площадь до 100 м2 на 1м этаже')
);
(sns
 .histplot(data=data[data['floor'] == 2]['total_area'], ax=axes[1], bins=30, binrange=(0,120))
 .set(title='Общая площадь до 120 м2 на 2м этаже')
);
(sns
 .histplot(data=data[data['floor'] == 3]['total_area'], ax=axes[2], bins=30, binrange=(0,150))
 .set(title='Общая площадь до 150 м2 на 3м этаже')
);

# %% [markdown]
# *Вывод:* данные корректны, аномальных значений нет. На приближенной гистограмме мы видим локальные максимумы. Эти максимуммы связаны с большим количеством типового строительства в России. Т.е. 30 и 50-метровых квартир действительно больше, чем 40-метровых - это нормально.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера: ❌</b>
#
# Давай все таки подпишем все графики и сделаем наш проект еще презентабельнее.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Добавил описание к графикам</div>

# %% [markdown]
# #### Атрибут *rooms* - количество комнат

# %% [markdown]
# **Посмотрим на количество различных значений**

# %%
data.value_counts(subset=['rooms'])
# Out:
# rooms
# 1        8036
# 2        7862
# 3        5565
# 4        1004
# 5         224
# 0         196
# 6          58
# 7          21
# 8           5
# 9           2
# 10          1
# 11          1
# dtype: int64

# %% [markdown]
# В общем картина кажется логичной - чем больше комнат, тем таких квартир меньше.
# Но бросаются в глаза 2 момента:
# - 196 квартир без комнат вообще
# - 9 квартир с 8 комнатами и более

# %%
data.query('rooms==0')['total_area'].describe()
# Out:
# count   196.00000
# mean     27.53628
# std       8.36857
# min      15.50000
# 25%      24.03750
# 50%      26.02500
# 75%      28.32500
# max      98.40000
# Name: total_area, dtype: float64

# %%
data.query('rooms==0').sort_values(by='total_area').tail(10)
# Out:
#        total_images     last_price  total_area first_day_exposition  rooms  \
# 4683              2  3650000.00000    35.00000           2018-02-01      0
# 9052             12  3890000.00000    38.30000           2017-10-06      0
# 16130            14  5000000.00000    42.10000           2018-04-13      0
# 7237              8  2999000.00000    42.63000           2017-11-27      0
# 15319             4  5970000.00000    43.30000           2017-07-20      0
# 10008            20  5050000.00000    44.20000           2017-09-14      0
# 13613            16  8100000.00000    58.40000           2019-04-26      0
# 21227             0  8200000.00000    71.00000           2017-07-21      0
# 3458              6  7400000.00000    73.60000           2017-05-18      0
# 20082            10 16300000.00000    98.40000           2017-11-08      0
#
#        ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# ...

# %% [markdown]
# Учитывая, что только 4 квартиры из списка квартир с 0 комнат имеют площадь больше 50 м², логично было бы предположить, что все эти квартиры являются однокомнатными.
# **Обновим количество комнат**

# %%
data['rooms'] = data['rooms'].replace(0, 1)

# %% [markdown]
# Теперь посмотрим на квартиры с большим количеством комнат.

# %%
data.query('rooms>7').sort_values(by='total_area')
# Out:
#        total_images     last_price  total_area first_day_exposition  rooms  \
# 8758              5 16100000.00000   150.00000           2018-07-10      8
# 648               3 17500000.00000   183.70000           2018-07-01     11
# 12447             8 19900000.00000   210.30000           2016-04-18      8
# 18119             4 15500000.00000   216.10000           2016-07-04     10
# 813               7 16500000.00000   229.00000           2016-02-25      8
# 8860             12 17000000.00000   235.00000           2018-07-14      9
# 18945             4 15800000.00000   236.40000           2015-02-19      8
# 20788             7 18000000.00000   245.00000           2017-04-06      8
# 13397            14 19500000.00000   309.70000           2016-02-03      9
#
#        ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 8758          2.92000       5.00000    107.00000      1   False      False
# ...

# %% [markdown]
# Видим, что это все квартиры с большой площадью (>150 м²). Так что здесь, похоже, что все нормально.

# %% [markdown]
# *Вывод:* Мы избавились от записей, в которых было **0** квартир, и поставили им значение **1**. Других аномальных значений найдено не было.

# %% [markdown]
# #### Атрибут *ceiling_height* - высота потолка

# %% [markdown]
# Начнем с изучения описания атрибута

# %%
data['ceiling_height'].describe()
# Out:
# count   22975.00000
# mean        2.71469
# std         0.99919
# min         1.00000
# 25%         2.60000
# 50%         2.65000
# 75%         2.70000
# max       100.00000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Настораживают минимальное и максимальное значения. Высота потолка в 100 метров, конечно, впечатляет, но скорее всего здесь ошибка в данных. Ошибка могла быть вызвана человеческим фактором - опечатка. Также это может быть техническая ошибка - например, высота указана в дюймах.
# **Отсортируем данные по высоте потолка и посмотрим хвосты.**

# %%
data.sort_values(by='ceiling_height').tail(30)
# Out:
#        total_images     last_price  total_area first_day_exposition  rooms  \
# 21227             0  8200000.00000    71.00000           2017-07-21      1
# 15743            14  5600000.00000    67.00000           2016-11-11      3
# 17442             0  5350000.00000    54.00000           2015-06-16      2
# 3474              3  1400000.00000    30.00000           2018-03-16      1
# 5863             20  5650000.00000    45.00000           2018-08-15      1
# 22309            20  5300000.00000    45.00000           2017-09-30      1
# 15061            19  5600000.00000    56.40000           2018-05-11      2
# 17496            15  6700000.00000    92.90000           2019-02-19      3
# 20507            12  5950000.00000    60.00000           2018-02-19      2
# 5076              0  3850000.00000    30.50000           2018-10-03      1
# 6246              6  3300000.00000    44.40000           2019-03-25      2
# ...

# %% [markdown]
# Квартира со 100 метровыми потолками больше похожа на ошибочную или тестовую строку: неправдоподобные данные, круглые значения в числах.
# **Удаляем эту запись из данных**

# %%
data = data.drop(index=22869)

# %% [markdown]
# Яндекс говорит, что минимальная комфортная для жизни высота потолка - 2.4 м.
# Поэтому будем считать, что значения от 24 м. до 32 м. ошибочны, и в них забыли добавить разделитель дробной части.
# **Разделим такие значения на 10**

# %%
data.loc[data['ceiling_height']>=24, 'ceiling_height'] /= 10

# %% [markdown]
# **Посмотрим количество записей с высотой потолков ниже 2.4 м и выше 6 м**

# %%
short_ciling_count = data.query('ceiling_height < 2.4')['ceiling_height'].count()
tall_ciling_count = data.query('ceiling_height > 6')['ceiling_height'].count()

print(f'Количество квартир с потолками ниже 2.4 м: {short_ciling_count} шт.'+
      f', это {round(short_ciling_count / len(data) * 100, 2)} %')
print(f'Количество квартир с потолками выше 6 м: {tall_ciling_count} шт.'+
      f', это {round(tall_ciling_count / len(data) * 100, 2)} %')
# Out:
# Количество квартир с потолками ниже 2.4 м: 21 шт., это 0.09 %
# Количество квартир с потолками выше 6 м: 8 шт., это 0.03 %

# %% [markdown]
# Можно считать такие данные не релевантными. Предположим, что здесь произошла ошибка в занесении данных. Можно предположить, что и другие атрибуты по таким записям не соответствуют действительности. Удалив эти записи мы потеряем чуть больше 0.1%, что не является критичным.
# **Удалим эти записи.**

# %%
data['ceiling_height'] = data.query('ceiling_height >= 2.4 and ceiling_height <= 6')['ceiling_height']

# %% [markdown]
# **Построим графики по обновленным данным**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 4, 4]})
fig.suptitle('Высота потолков по обновленным данным', fontsize=16)

fig.tight_layout()
sns.boxplot(y=data['ceiling_height'], ax=axes[0]);
fig.tight_layout()
sns.histplot(data=data['ceiling_height'], ax=axes[1], bins=30);
fig.tight_layout()
sns.violinplot(y=data['ceiling_height'], ax=axes[2]);

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Обрати внимание, что наши действия повторяются с точки зрения построения графиков.
#
# Это говорит о том, что мы можем создать функцию, которая будет выполнять все действия за нас.
#
# Тем самым мы сможем оптимизировать свой код и проект целиком.
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Согласен. Можно не переделывать в этом проекте уже?</div>

# %%
data['ceiling_height'].describe()
# Out:
# count   22945.00000
# mean        2.68684
# std         0.20121
# min         2.40000
# 25%         2.60000
# 50%         2.65000
# 75%         2.70000
# max         5.80000
# Name: ceiling_height, dtype: float64

# %%
tall_ciling_count = data.query('ceiling_height > 3')['ceiling_height'].count()

print(f'Количество квартир с потолками выше 3 м: {tall_ciling_count} шт.'+
      f', это {round(tall_ciling_count / len(data) * 100, 2)} %')
# Out:
# Количество квартир с потолками выше 3 м: 1225 шт., это 5.33 %

# %% [markdown]
# Локальные максимумы опять связаны с типовым строительством. Большинство жилья имеет одну и ту же высоту потолка.
# При обработке пропущенных значений мы поставили медианное значение, с этим связано большое количество квартир с высотой потолка 2.65 м.
# **Посчитаем медиану для изначального набора данных, только на этот раз сначала избавимся от аномальных значений.**

# %%
data_ceiling = raw_data.copy()
data_ceiling.loc[data_ceiling['ceiling_height'] >= 24, 'ceiling_height'] /= 10
data_ceiling['ceiling_height'] = data_ceiling.query('ceiling_height >= 2.4 and ceiling_height <= 6')['ceiling_height']

ceiling_median = round(data_ceiling['ceiling_height'].median(), 2)
print(f'Медианная высота потолков: {ceiling_median} м.')
# Out:
# Медианная высота потолков: 2.65 м.

# %% [markdown]
# *Вывод:* Мы исправили данные, которые посчитали опечаткой. Данные, ошибку в которых не смогли объяснить, было решено удалить. Удалено было примерно 0.1% данных. На примере убедились, что медиана позволяет заменять пустые данные в момент обработки пропущенных значений. Удаление аномальных значений не сильно влияет на медиану.

# %% [markdown]
# #### Атрибут *floors_total* - количество этажей в доме

# %% [markdown]
# Начнем с изучения описания атрибута

# %%
data['floors_total'].describe()
# Out:
# count   22974.00000
# mean       10.74689
# std         6.63461
# min         1.00000
# 25%         5.00000
# 50%         9.00000
# 75%        16.00000
# max        60.00000
# Name: floors_total, dtype: float64

# %% [markdown]
# **Построим гистограмму и график-скрипку**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
fig.suptitle('Количество этажей в доме', fontsize=16)

fig.tight_layout()
sns.histplot(data=data['floors_total'], ax=axes[0], bins=40);
sns.violinplot(y=data['floors_total'], ax=axes[1]);

# %%
data.value_counts(subset=['floors_total']).head(10)
# Out:
# floors_total
# 5.00000         5681
# 9.00000         3724
# 16.00000        1362
# 12.00000        1332
# 10.00000        1153
# 4.00000         1145
# 25.00000        1069
# 17.00000         829
# 6.00000          813
# 3.00000          647
# dtype: int64

# %%
data.sort_values(by='floors_total').tail()
# Out:
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 397              15 5990000.00000    54.00000           2018-03-22      2
# 11079            16 9200000.00000    75.00000           2019-02-22      2
# 16934             5 4100000.00000    40.00000           2017-10-17      1
# 16731             9 3978000.00000    40.00000           2018-09-24      1
# 2253             12 3800000.00000    45.50000           2018-06-28      2
#
#        ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 397           2.65000      36.00000     21.40000     28   False      False
# 11079         2.70000      36.00000     40.00000     29   False      False
# 16934             NaN      37.00000     17.40000      5   False      False
# 16731         2.65000      52.00000     10.50000     18   False      False
# 2253          2.88000      60.00000     27.40000      4   False      False
#
#        kitchen_area  balcony    locality_name locality_clean_name  \
# ...

# %% [markdown]
# *Вывод:* Мы снова видим особенности типового строительства. Локальные пики соответствуют 5, 9, 16 и 25 этажным домам. Есть вопросики к двум квартирам, расположенным в 60 и 52 этажных домах. Википедия говорит, что самое высокое здание СПб - Лахта Центр. В нем 88 этажей. Я не нашел информации, что в нем вообще есть квартиры, и на момент исследования в 2022м году здание еще не закончено. Следующее по высоте жилое здание - 42 этажа. Скорее всего 60 этажей -  это 6 этажей. 52 этажа: здесь сложнее понять в чем ошибка. В любом случае я решил не удалять эти данные, они вряд ли как-то отразятся на результатах.

# %% [markdown]
# #### Атрибут *living_area* - жилая площадь квартиры

# %% [markdown]
# **Построим графики**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 4, 4]})
fig.suptitle('Жилая площадь', fontsize=16)

fig.tight_layout()
sns.boxplot(y=data['living_area'], ax=axes[0]);
fig.tight_layout()
sns.histplot(data=data['living_area'], ax=axes[1], bins=30);
fig.tight_layout()
sns.violinplot(y=data['living_area'], ax=axes[2]);

# %% [markdown]
# Выглядит правдоподобно, но непонятно почему квартир с жилой площадью 18-28 м² резко меньше.

# %%
data.query('27 > living_area > 19')
# Out:
#        total_images    last_price  total_area first_day_exposition  rooms  \
# 10                5 5050000.00000    39.60000           2017-11-16      1
# 15               16 4650000.00000    39.00000           2017-11-18      1
# 18                8 3250000.00000    31.00000           2017-01-27      1
# 28                8 4170000.00000    44.00000           2017-12-13      1
# 50                1 4500000.00000    48.20000           2017-11-13      1
# ...             ...           ...         ...                  ...    ...
# 23652             5 4550000.00000    42.40000           2015-07-19      1
# 23654            17 2850000.00000    45.70000           2017-03-13      1
# 23655             1 2414306.00000    40.50000           2016-09-08      1
# 23678            10 3500000.00000    43.00000           2016-05-19      2
# 23687             6 3200000.00000    39.00000           2017-12-16      1
#
#        ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
fig.suptitle('Жилая площадь в зависимости от этажа', fontsize=16)

fig.tight_layout()
(sns
 .histplot(data=data[data['floor'] == 1]['living_area'], ax=axes[0], bins=30)
 .set(title='Жилая площадь на 1м этаже')
);
(sns
 .histplot(data=data[data['floor'] == 2]['living_area'], ax=axes[1], bins=30)
 .set(title='Жилая площадь на 2м этаже')
);
(sns
 .histplot(data=data[data['floor'] == 3]['living_area'], ax=axes[2], bins=30)
 .set(title='Жилая площадь на 3м этаже')
);

# %%
# sns.lmplot(data=data, x='living_area', y='rooms', hue='studio', palette='Set2', alpha=0.8);
(data
 .plot(kind='scatter', x='living_area', y='rooms', alpha=0.3, figsize=(15, 6))
 .set(title='Зависимость жилой площади от этажа')
);

# %% [markdown]
# *Вывод:* Рассмотрев различные графики и срезы, не удалось сделать однозначный вывод по небольшому числу квартир с жилой площадью от 19 до 27 метров. Этот промежуток приходится на 1, 2 и 3-х комнатные квартиры. По всем этим объектам наблюдается аналогичная ситуация. Счтаем данные корректными.

# %% [markdown]
# #### Атрибут *floor* - этаж

# %% [markdown]
# Начнем с изучения описания атрибута

# %%
data['floor'].describe()
# Out:
# count   22974.00000
# mean        5.89580
# std         4.90203
# min         1.00000
# 25%         2.00000
# 50%         4.00000
# 75%         8.00000
# max        33.00000
# Name: floor, dtype: float64

# %% [markdown]
# **Построим гистограмму**

# %%
sns.histplot(data=data['floor'], bins=30).set(title='Распределение этажей');

# %% [markdown]
# *Вывод:* Никаких претензий. Должен же быть и такой атрибут.

# %% [markdown]
# #### Атрибуты *studio* и *open_plan* - студия и свободная планировка

# %% [markdown]
# Данные атрибуты имеют булев тип, т.е. принимают значения `True` и `False`
# **Построим сводную таблицу и посмотрим количественный состав.**

# %%
studio_count = data.query('studio')['studio'].count()
open_plan_count = data.query('open_plan')['open_plan'].count()

print(f'Количество квартир-студий: {studio_count} шт.'+
      f', это {round(studio_count / len(data) * 100, 2)} %')
print(f'Количество квартир со свободной планировкой: {open_plan_count} шт.'+
      f', это {round(open_plan_count / len(data) * 100, 2)} %')
# Out:
# Количество квартир-студий: 149 шт., это 0.65 %
# Количество квартир со свободной планировкой: 65 шт., это 0.28 %

# %% [markdown]
# *Вывод:* квартир-студий и квартир со свободной планировкой в выборке очень мало. Удалять атрибуты не будем, но вряд ли получится сделать много выводов по такой выборке.

# %% [markdown]
# #### Атрибут *kitchen_area* - площадь кухни

# %% [markdown]
# **Построим графики**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5), gridspec_kw={'width_ratios': [1, 4, 4]})
fig.suptitle('Площадь кухни в зависимости от этажа', fontsize=16)

fig.tight_layout()
sns.boxplot(y=data['living_area'], ax=axes[0]);
fig.tight_layout()
sns.histplot(data=data['kitchen_area'], ax=axes[1], bins=30);
fig.tight_layout()
sns.violinplot(y=data['kitchen_area'], ax=axes[2]);

# %%
data['kitchen_area'].describe()
# Out:
# count   20778.00000
# mean       10.11375
# std         4.72095
# min         1.30000
# 25%         7.00000
# 50%         9.00000
# 75%        11.50750
# max       100.70000
# Name: kitchen_area, dtype: float64

# %%
data.query('kitchen_area > 80')
# Out:
#       total_images     last_price  total_area first_day_exposition  rooms  \
# 2489             9 12500000.00000   255.00000           2017-04-21      3
#
#       ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 2489         2.65000       2.00000    153.90000      2   False      False
#
#       kitchen_area  balcony    locality_name locality_clean_name  \
# 2489     100.70000  0.00000  Санкт-Петербург     Санкт-Петербург
#
#       airports_nearest  city_center_dist  parks_around_3k  parks_nearest  \
# 2489       29544.00000        6916.00000          0.00000            NaN
#
#       ponds_around_3k  ponds_nearest  days_exposition
# 2489          3.00000      198.00000        102.00000

# %% [markdown]
# *Вывод:* аномальных значений нет. Есть 1 квартира с кухней в 100 квадратных метров - что ж, красиво жить не запретишь.

# %% [markdown]
# #### Атрибут *balcony* - число балконов

# %% [markdown]
# **Посмотрим на распредение по числу балконов.**

# %%
data.value_counts(subset=['balcony'])
# Out:
# balcony
# 0.00000    14761
# 1.00000     4074
# 2.00000     3609
# 5.00000      287
# 4.00000      167
# 3.00000       76
# dtype: int64

# %% [markdown]
# *Вывод:* аномальных значений не обнаружено.

# %% [markdown]
# #### Атрибуты *airports_nearest*, *city_center_dist*, *parks_nearest* и *ponds_nearest*

# %% [markdown]
# **Построим гистограммы для всех атрибутов**

# %%
fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(15, 5))

fig.tight_layout()
(sns
 .histplot(data=data['airports_nearest'], ax=axes[0], bins=30)
 .set(title='Расстояние до аэропорта')
);
fig.tight_layout()
(sns
 .histplot(data=data['city_center_dist'], ax=axes[1], bins=30)
 .set(title='Расстояние до центра СПб')
);
fig.tight_layout()
(sns
 .histplot(data=data['parks_nearest'], ax=axes[2], bins=30)
 .set(title='Расстояние до ближайшего парка')
);
fig.tight_layout()
(sns
 .histplot(data=data['ponds_nearest'], ax=axes[3], bins=30)
 .set(title='Расстояние до ближайшего водоема')
);

# %%
data.query('city_center_dist > 50000')['locality_clean_name'].unique()
# Out:
# array(['Ломоносов', 'Кронштадт', 'Зеленогорск', 'Молодежное'],
#       dtype=object)

# %% [markdown]
# *Вывод:* все графики поддаются интуитивной логике. Аномальных занчений не обнаружено. Атрибут `city_center_dist` показывает расстояние не до центра нас. пункта, в котором находится объект, а до центра Санкт-Петербурга.

# %% [markdown]
# ### Предобработка. Вывод

# %% [markdown]
# После предобработки данных у нас отсталось 22974 из 23699 изначальных строк. Мы удалили около 3%, это не большое количество, но это добавляет качества данным.
# В целом присланные данные оказались довольно высокого качества. Больше всего усилий потребовали атрибуты `locality_name` и `last_price`, т.к. это очень чувствительные атрибуты. В `locality_name` было много дубликатов, после обработки количество уникальных нас. пунктов уменьшилось на 20%. В `last_price` был слишком длинный хвост из квартир с высокой стоимостью, что могло негативно отразиться на дальнейшем анализу.

# %% [markdown]
# ## Дополнительные данные

# %% [markdown]
# Для дальнейшего анализа добавим следующие атрибуты:
# - цена квадратного метра
# - день недели публикации объявления
# - месяц публикации объявления
# - год публикации одъявления
# - тип этажа квартиры
# - расстояние до центра города в километрах

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# Цена одного квадратного метра рассчитывается как частное атрибутов `last_price` и `total_area`.

# %%
data.insert(loc=2,
            column='price_per_meter',
            value=data['last_price'] / data['total_area']
           )

# %%
# Округлим стоимость кв. метра до целого значения, большая точность здесь не важна
data['price_per_meter'] = data['price_per_meter'].astype('Int64', errors='ignore')
data.head()
# Out:
#    total_images     last_price  price_per_meter  total_area  \
# 0            20 13000000.00000     120370.37037   108.00000
# 1             7  3350000.00000      82920.79208    40.40000
# 2            10  5196000.00000      92785.71429    56.00000
# 4             2 10000000.00000     100000.00000   100.00000
# 5            10  2890000.00000      95065.78947    30.40000
#
#   first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 0           2019-03-07      3         2.70000      16.00000     51.00000
# 1           2018-12-04      1         2.65000      11.00000     18.60000
# 2           2015-08-20      2         2.65000       5.00000     34.30000
# 4           2018-06-19      2         3.03000      14.00000     32.00000
# 5           2018-09-10      1         2.65000      12.00000     14.40000
#
#    floor  studio  open_plan  kitchen_area  balcony              locality_name  \
# 0      8   False      False      25.00000  0.00000            Санкт-Петербург
# ...

# %% [markdown]
# ### Разнесение даты публикации объявления

# %% [markdown]
# **Разобьем дату публикации объявления на 3 новых атрибута - `exp_week_day`, `exp_month` и `exp_year`.**

# %%
data.insert(loc=5,
            column='exp_week_day',
            value=data['first_day_exposition'].dt.dayofweek
           )
data.insert(loc=6,
            column='exp_month',
            value=data['first_day_exposition'].dt.month
           )
data.insert(loc=7,
            column='exp_year',
            value=data['first_day_exposition'].dt.year
           )
data.head()
# Out:
#    total_images     last_price  price_per_meter  total_area  \
# 0            20 13000000.00000     120370.37037   108.00000
# 1             7  3350000.00000      82920.79208    40.40000
# 2            10  5196000.00000      92785.71429    56.00000
# 4             2 10000000.00000     100000.00000   100.00000
# 5            10  2890000.00000      95065.78947    30.40000
#
#   first_day_exposition  exp_week_day  exp_month  exp_year  rooms  \
# 0           2019-03-07             3          3      2019      3
# 1           2018-12-04             1         12      2018      1
# 2           2015-08-20             3          8      2015      2
# 4           2018-06-19             1          6      2018      2
# 5           2018-09-10             0          9      2018      1
#
#    ceiling_height  floors_total  living_area  floor  studio  open_plan  \
# 0         2.70000      16.00000     51.00000      8   False      False
# ...

# %% [markdown]
# ### Тип этажа квартиры

# %% [markdown]
# **Добавим атрибут `floor_type` на основе атрибута `floor`. Нам нужно разделить первые, последние и все остальные этажи.**

# %%
def find_floor_type(row):
    '''
    Функция для определения типа этажа.
    Используемые типы:
    - Первый
    - Последний
    - Другой
    '''
    if row['floor'] == 1:
        return 'Первый'
    elif row['floor'] == row['floors_total']:
        return 'Последний'
    return 'Другой'


data.insert(loc=13,
            column='floor_type',
            value=data.apply(find_floor_type, axis=1)
           )
data.head()
# Out:
#    total_images     last_price  price_per_meter  total_area  \
# 0            20 13000000.00000     120370.37037   108.00000
# 1             7  3350000.00000      82920.79208    40.40000
# 2            10  5196000.00000      92785.71429    56.00000
# 4             2 10000000.00000     100000.00000   100.00000
# 5            10  2890000.00000      95065.78947    30.40000
#
#   first_day_exposition  exp_week_day  exp_month  exp_year  rooms  \
# 0           2019-03-07             3          3      2019      3
# 1           2018-12-04             1         12      2018      1
# 2           2015-08-20             3          8      2015      2
# 4           2018-06-19             1          6      2018      2
# 5           2018-09-10             0          9      2018      1
#
#    ceiling_height  floors_total  living_area  floor floor_type  studio  \
# 0         2.70000      16.00000     51.00000      8     Другой   False
# ...

# %% [markdown]
# ### Расстояние до центра города в километрах

# %% [markdown]
# **Добавим атрибут `city_center_dist_km`. Здесь все аналогично  добавлению цены за квадратный метр.**

# %%
data.insert(loc=22,
            column='city_center_dist_km',
            value=round(data['city_center_dist'] / 1000,  0)
           )

# %%
# Округлим расстояние до центра города
# data['city_center_dist_km'] = data['city_center_dist_km'].astype('Int64', errors='ignore')
data.head()
# Out:
#    total_images     last_price  price_per_meter  total_area  \
# 0            20 13000000.00000     120370.37037   108.00000
# 1             7  3350000.00000      82920.79208    40.40000
# 2            10  5196000.00000      92785.71429    56.00000
# 4             2 10000000.00000     100000.00000   100.00000
# 5            10  2890000.00000      95065.78947    30.40000
#
#   first_day_exposition  exp_week_day  exp_month  exp_year  rooms  \
# 0           2019-03-07             3          3      2019      3
# 1           2018-12-04             1         12      2018      1
# 2           2015-08-20             3          8      2015      2
# 4           2018-06-19             1          6      2018      2
# 5           2018-09-10             0          9      2018      1
#
#    ceiling_height  floors_total  living_area  floor floor_type  studio  \
# 0         2.70000      16.00000     51.00000      8     Другой   False
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Мы достаточно детально обработали наши данные и добавили все необходимые значения в нашу выборку. Давай теперь проведём анализ.
#
# </div>

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Анализ значимых параметров

# %% [markdown]
# После предобработки данные стали качественнее. Для анализа данных посмотрим еще раз на атрибуты и их гистограммы.
# Значимыми атрибутами являются:
# - общая площадь
# - жилая площадь
# - площадь кухни
# - цена объекта
# - количество комнат
# - высота потолков
# - этаж квартиры
# - тип этажа квартиры
# - общее количество этажей в доме
# - расстояние до центра города
# - расстояние до ближайшего аэропорта
# - расстояние до ближайшего парка
# - день и месяц публикации объявления

# %% [markdown]
# #### Общая площадь, жилая площадь и площадь кухни

# %% [markdown]
# **Построим гистограммы**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
fig.suptitle('Распределение площадей', fontsize=16)

fig.tight_layout()
sns.histplot(data=data['total_area'], ax=axes[0], bins=30).set(title='Общая площадь');
fig.tight_layout()
sns.histplot(data=data['living_area'], ax=axes[1], bins=30).set(title='Жилая площадь');
fig.tight_layout()
sns.histplot(data=data['kitchen_area'], ax=axes[2], bins=30).set(title='Площадь кухни');

# %%
sns.pairplot(data.loc[:, ['total_area', 'living_area', 'kitchen_area']]);

# %%
data.loc[:, ['total_area', 'living_area', 'kitchen_area']].corr()
# Out:
#               total_area  living_area  kitchen_area
# total_area       1.00000      0.92725       0.52878
# living_area      0.92725      1.00000       0.29253
# kitchen_area     0.52878      0.29253       1.00000

# %%
data['total_area'].describe(percentiles=[.25, .5, .75, .9, .95])
# Out:
# count   22974.00000
# mean       56.67741
# std        24.60862
# min        12.00000
# 25%        40.00000
# 50%        51.00000
# 75%        67.00000
# 90%        86.90000
# 95%       101.00000
# max       320.00000
# Name: total_area, dtype: float64

# %% [markdown]
# *Вывод:* мы видим, что в основном на рынке жилья присутствуют квартиры общей площадью до 100 м². Данная площадь приходится почти на 95% продаваемого жилья. Но также продаются и большие квартиры площадью 300 м² и даже больше.
# &emsp;Особенностью рынка жилья в России, и в Ленинградской области в частности, является типовое строительство. Отсюда логичным следствием являются локальные макисмумы около некоторых значений жилой площади. Например, это 32 м² для однокомнатных квартир, 44 - двухкомнатных, 52 - трехкомнатных.
# &emsp;График рессеяния и матрица корреляции показывают нам очень сильную прямую связь между общей площадью квартиры и жилой площадью. Также есть прямая связь между общей площадью и площадью кухни, но уже не так сильна. Видимо есть какой-то логичный предельный размер кухни (около 40 м²), что в целом абсолютно логично. Вряд ли кому-то нужна кухня площадью 100 м², хотя даже такое предложение есть на рынке. Прямая связь между жилой площадью и площадью кухни тоже есть, но она уже совсем слабая.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Хорошие и логичные комментарии. Очень важно строить график корреляции между переменными, ведь может произойти такая ситуация, что расчет у нас очень сильный а на графике абсолютно другая картина.
#
# ---
#
# В том числе можно было построить матрицу корреляции между нужными нам переменными.
#
# И визуализировать её с помощью метода `heatmap` из библиотеки `seaborn`.
#
# </div>

# %% [markdown]
# #### Цена объекта

# %%
sns.histplot(data=data['last_price'], bins=30).set(title='Распределение стоимостей');

# %% [markdown]
# *Вывод:* последняя стоимость очевидно является основным атрибутом для продаваемого объекта недвижимости. По гистограмме мы видим, что основная масса квартир (51 %) стоит от 2 до 5 млн. руб.
# Распределение относится к распределениям Пуассона. Заметен довольно резкий рост к среднему значению и длинный хвост (9 %) из квартир стоимостью больше 10 млн. руб.

# %% [markdown]
# #### Количество комнат и высота потолков

# %% [markdown]
# **Построим гистограммы**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.tight_layout()
sns.histplot(data=data['rooms'], ax=axes[0], bins=11).set(title='Количество комнат');
fig.tight_layout()
sns.histplot(data=data['ceiling_height'], ax=axes[1], bins=30).set(title='Высота потолков');

# %%
lot_of_rooms = data.query('rooms > 4')['rooms'].count()

print(f'Количество квартир с 5 и более комнатами: {lot_of_rooms} шт.'+
      f', это {round(lot_of_rooms / len(data) * 100, 2)} %')
# Out:
# Количество квартир с 5 и более комнатами: 312 шт., это 1.36 %

# %% [markdown]
# *Вывод:* по гистограмме количества комнат видно, что основными продаваемыми квартирами (да и в целом скорее всего тоже) являются 1 и 2 комнатные квартиры. Интуитивно понятно, что чем больше комнат, тем таких квартир меньше. Этот интуитивный вывод подтверждается данными. Больше 98% квартир имеют 4 или меньше комнат. И всего 312 квартир имеют больше 4 комнат. Максимальное количество комнат - 11.
# &emsp;Большое количество данных по высоте потолков не было заполнено и поэтому заменено на медианное значение - 2.65 м. Отсюда вытекает такой сильный максимум на гистограмме. Вообще гистограмма высоты потолков отражает стандартизацию строительства. Я бы интуитивно предположил, что в Санкт-Петербурге будут довольно высокие потолки из-за его исторической застройки. Но данные опровергают данное предположение. Скорее всего это связано с тем, что предложений по квартирам в домах исторического центра намного меньше, чем предложений из районов-спальников.

# %% [markdown]
# #### Этажи

# %% [markdown]
# **Построим гистограммы**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.tight_layout()
sns.histplot(data=data['floor'], ax=axes[0], bins=30).set(title='Этаж');
fig.tight_layout()
sns.histplot(data=data['floors_total'], ax=axes[1], bins=40).set(title='Количество этажей в доме');

# %% [markdown]
# **Типы этажей выведем списком**

# %%
(data
 .value_counts(subset=['floor_type'], normalize=True) * 100
 ).astype('int')
# Out:
# floor_type
# Другой        73
# Последний     13
# Первый        12
# dtype: int32

# %% [markdown]
# *Вывод:* бóльшая часть квартир - относительно других этажей по отдельности - находится на первых этажах зданий - 12%. Это аболютно логично, т.к. первые этажи есть в каждом здании. Последний этаж тоже есть в каждом доме, но для одноэтажных домов мы относили квартиры к первому этажу, а не к последнему.
# &emsp;Вообще по гистограмме этажей видно, что номинальное большинство квартир находятся не выше 5го этажа. Это косвенно говорит о большом количестве хрущевок.
# &emsp;Это предположение подтверждается гистограммой высотности зданий. Здесь мы снова видим особенности типового строительства. Локальные пики соответствуют 5, 9, 16 и 25 этажным домам.
# &emsp;На последнийх этажах находятся 13% квартир из нашей таблицы данных.
# &emsp;Очевидно, что не на первом и последнем этажах находится абсолютное большинство квартир - 73%.

# %% [markdown]
# #### Расстояния до центра СПб, аэропорта и ближайшего парка

# %% [markdown]
# **Построим гистограммы**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

fig.tight_layout()
(sns
 .histplot(data=data['city_center_dist_km'], ax=axes[0], bins=30)
 .set(title='Расстояния до центра СПб')
);
fig.tight_layout()
(sns
 .histplot(data=data['airports_nearest'], ax=axes[1], bins=30)
 .set(title='Расстояния до аэропорта')
);
fig.tight_layout()
(sns
 .histplot(data=data['parks_nearest'], ax=axes[2], bins=30)
 .set(title='Расстояния до ближайшего парка')
);

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
out_of_spb = (data
              .query('city_center_dist_km > 15')['city_center_dist_km']
              )
park_near = (data
             .query('parks_nearest < 1000')['parks_nearest']
             )

print(f'Количество квартир на расстоянии больше 15 км от центра: {out_of_spb.count()} шт.'+
      f', это {round(out_of_spb.count() / len(data[~data["city_center_dist_km"].isna()]) * 100, 2)} %')
print(f'Количество квартир с парками ближе 1 км: {park_near.count()} шт.'+
      f', это {round(park_near.count() / len(data[~data["parks_nearest"].isna()]) * 100, 2)} %')
# Out:
# Количество квартир на расстоянии больше 15 км от центра: 5603 шт., это 32.07 %
# Количество квартир с парками ближе 1 км: 7201 шт., это 95.28 %

# %% [markdown]
# *Вывод:* бóльшая часть квартир находится на расстоянии 5-15 км от центра Санкт-Петербурга. Это можно объяснить тем, что на этом расстоянии находится большинство спальных районов - в том числе известный Мурино.
# &emsp;Количество квартир в области (> 15 км) намного меньше - 32%.
# &emsp;При этом расстояние до аэропорта распределено довольно равномерно. Жилья на расстоянии от 15 до 40 км от аэропорта примерно одинковое количество. Это говорит о небольшом количество аэропортов.
# &emsp;Последний график говорит нам о том, что 95% квартир расположены рядом с парками, до которых идти меньше 1 км. Это очень хороший показатель города!

# %% [markdown]
# #### Время публикации объявления

# %% [markdown]
# **Построим гистограммы**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

fig.tight_layout()
sns.histplot(data=data['exp_week_day'], ax=axes[0], bins=7).set(title='День недели');
fig.tight_layout()
sns.histplot(data=data['exp_month'], ax=axes[1], bins=12).set(title='Месяц публикации');

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Как аналог можно было бы использовать также цикл `for`, чтобы автоматизировать построение графиков.
#
# </div>

# %%
work_days = (data
              .query('exp_week_day in (0, 1, 2, 3, 4)')['exp_week_day']
              )
wend_days = (data
             .query('exp_week_day in (5, 6)')['exp_week_day']
             )

print(f'Количество объявлений, опубликованных в будние дни: {work_days.count()} шт.'+
      f', это {round(work_days.count() / len(data) * 100, 2)} %')
print(f'Количество объявлений, опубликованных в выходные дни: {park_near.count()} шт.'+
      f', это {round(wend_days.count() / len(data) * 100, 2)} %')
# Out:
# Количество объявлений, опубликованных в будние дни: 19446 шт., это 84.64 %
# Количество объявлений, опубликованных в выходные дни: 7201 шт., это 15.36 %

# %%
feb_apr = (data
           .query('exp_month in (2, 3, 4)')['exp_month']
           )
may = (data
       .query('exp_month == 5')['exp_month']
       )
jun_aug = (data
           .query('exp_month in (6, 7, 8)')['exp_month']
           )
dec_jan = (data
           .query('exp_month in (12, 1)')['exp_month']
           )

print(f'Количество объявлений, опубликованных в феврале - апреле: {feb_apr.count()} шт.'+
      f', это {round(feb_apr.count() / len(data) * 100, 2)}%'+
      f', среднее: {int(feb_apr.count() / 3)}'
      )
print(f'Количество объявлений, опубликованных в мае: {may.count()} шт.'+
      f', это {round(may.count() / len(data) * 100, 2)}%')
print(f'Количество объявлений, опубликованных в июне - августе: {jun_aug.count()} шт.'+
      f', это {round(jun_aug.count() / len(data) * 100, 2)}%'+
      f', среднее: {int(jun_aug.count() / 3)}'
      )
print(f'Количество объявлений, опубликованных в декабре и январе: {dec_jan.count()} шт.'+
      f', это {round(dec_jan.count() / len(data) * 100, 2)}%'+
      f', среднее: {int(dec_jan.count() / 2)}'
      )
# Out:
# Количество объявлений, опубликованных в феврале - апреле: 7393 шт., это 32.18%, среднее: 2464
# Количество объявлений, опубликованных в мае: 1234 шт., это 5.37%
# Количество объявлений, опубликованных в июне - августе: 5037 шт., это 21.92%, среднее: 1679
# Количество объявлений, опубликованных в декабре и январе: 3021 шт., это 13.15%, среднее: 1510

# %% [markdown]
# *Вывод:* время публикации показывает интересные результаты.
# &emsp;В будние дни публикуется почти одинаковое количество объявлений. Чуть меньше (на 10%) публикуют в понедельник.
# &emsp;При этом всего в будние дни публикуется 85% объявлений, в выходные - 15%. В будние публикуется около 3700 объвлений в день, в выходные - около 1700.
# &emsp;Если смотреть разбивку по месяцам, то больше всего объявлений было опубликовано в периоде с февраля по апрель. Среднее количество объявлений в эти месяцы - 2464 шт.
# &emsp;В мае люди, видимо, уезжают на дачи или в отпуск, и объявлений становится почти в 2 раза меньше - 1234.
# &emsp;Дальше идут летние месяцы низкой активности - 1680 объявлений в месяц. И с сентября снова начинается рост к объемам февраля - апреля.
# &emsp;Декабрь и январь снова являются месяцами-затишьями - 1500 объявлений в месяц. Это снижение можно связать с предстоящими новогодними праздниками, которые являются основными выходными датами в России.

# %% [markdown]
# ### Анализ скорости продажи квартир

# %% [markdown]
# **Построим гистограмму**

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))
fig.suptitle('Скорость продажи квартир', fontsize=16)

fig.tight_layout()
(sns
 .histplot(data=data['days_exposition'], ax=axes[0], bins=30)
 .set(title='Весь набор данных')
);
fig.tight_layout()
(sns
 .histplot(data=data['days_exposition'], ax=axes[1], bins=30, binrange=(0, 400))
 .set(title='До 400 дней')
);
fig.tight_layout()
(sns
 .histplot(data=data['days_exposition'], ax=axes[2], bins=30, binrange=(0, 100))
 .set(title='До 100 дней')
);

# %%
data['days_exposition'].describe(percentiles=[.05, .1, .2, .5, .8, .9, .95])
# Out:
# count   19997.00000
# mean      177.86953
# std       216.50197
# min         1.00000
# 5%          9.00000
# 10%        17.00000
# 20%        34.00000
# 50%        94.00000
# 80%       282.00000
# 90%       450.00000
# 95%       635.00000
# max      1580.00000
# Name: days_exposition, dtype: float64

# %% [markdown]
# *Вывод:* средняя продолжительность размещения объявления - 178 дней. Это намного больше, чем медиана - 94 дня. Это связано с большим количеством слишком долгих продаж. Долгие продажи часто связаны с нерыночными условиями предложения.
# &emsp;Изучив различные срезу распределения скорости продажи, можно прийти к выводу, что быстрой продажей можно считать продажу менее чем за 35 дней - 20% сделок.
# &emsp;Слишком длительной продажей можно считать значение - год. Таких сделок около 15%.

# %% [markdown]
# ### Оценка влияния на стоимость квартиры

# %% [markdown]
# Можно сделать предположение, что основными факторами, влияющими на стоимость квартиры, являются:
# - общая площадь
# - жилая площадь
# - площадь кухни
# - количество комнат
# - этаж, на котором расположена квартира
# - дата размещения
#
# Для проверки предположений посмотрим на коэффициент корреляции между стоимостью квартиры и указанными атрибутами.

# %%
# Список атрибутов для построения корреляции
corr_columns = ['last_price',
                'total_area',
                'living_area',
                'kitchen_area',
                'rooms',
                # 'floor_type',  # не является числовым
                'exp_week_day',
                'exp_month',
                'exp_year'
               ]

# Создадим новый датафрейм для матрицы корреляции
price_corr = pd.DataFrame()
'''
Проходим по каждому атрибуту из corr_columns и добавляем корреляцию
по нему к last_price в датафрейм price_corr
'''
for col in corr_columns:
    price_corr.loc['last_price', col] = data.corr().loc['last_price', col]

price_corr
# Out:
# C:\Users\denis\AppData\Local\Temp/ipykernel_12040/1488150799.py:20: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   price_corr.loc['last_price', col] = data.corr().loc['last_price', col]
# C:\Users\denis\AppData\Local\Temp/ipykernel_12040/1488150799.py:20: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   price_corr.loc['last_price', col] = data.corr().loc['last_price', col]
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Кстати можно отключить предупреждения с помощью следующего способа ниже.
#
# `import warnings`
#
# `warnings.simplefilter('ignore')`
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Да пусть будут. Больше знать буду.</div>

# %% [markdown]
# **Посмотрим на графики рассеивания по этим атрибутам**

# %%
sns.pairplot(data.loc[:, corr_columns]);

# %% [markdown]
# **Оценка стоимости по этажу квартиры**

# %%
spb_price_by_floor = (data
                      .pivot_table(index='floor_type',
                                   values='last_price',
                                   aggfunc='median'
                                   )
                      )

spb_price_by_floor.plot(kind='bar', figsize=(15, 5));
plt.title('Стоимость квартиры от типа этажа')
plt.show;

# %%
spb_price_by_floor
# Out:
#               last_price
# floor_type
# Другой     4750000.00000
# Первый     3899000.00000
# Последний  4200000.00000

# %% [markdown]
# *Вывод:* мы построили зависимости стоимости квартиры от различных атрибутов и выяснили:
# 1. Стоимость имеет прямую и самую сильную корреляцию с общей площадью квартиры.
# 2. Чуть меньше, но тоже сильная, сввязь с жилой площадью и площадью кухни. Это объясняется сильной свзяью между общей площадью и жилыми с кухней. Все это видно на графиках рассевания.
# 3. Чем больше комнат, тем выше стоимость квартиры. Это утвержддение также косвенно связано с тем, что количество комнат прямо связано с общей площадью.
# 4. Этаж влияет на стоимость квартиры. За последний этаж в среднем предлагают 12% дисконта, за первый  - 18%.
# 5. А вот с временем публикации стоимость квартир никак не связана. Здесь все распределено довольно ровно, коэффициент корреляции близок к нулю.

# %% [markdown]
# ### Оценка средней цены по городам

# %% [markdown]
# **Построим сводную таблицу по разным населенным пунктам**

# %%
# создадим новую переменную для среза
price_by_loc = data.pivot_table(index='locality_clean_name'
                                ,values='last_price'
                                ,aggfunc=['count', 'mean', 'median']
                                )
price_by_loc.columns = ['count', 'mean',  'median']

price_by_loc.sort_values(by='count', ascending=False).head(10)
# Out:
#                      count          mean        median
# locality_clean_name
# Санкт-Петербург      15015 6433139.81272 5400000.00000
# Мурино                 590 3678462.20339 3400000.00000
# Кудрово                472 4358688.05085 3890000.00000
# Шушары                 440 4108081.81591 3950000.00000
# Всеволожск             397 3737118.55164 3450000.00000
# Пушкин                 360 5899602.67778 5150000.00000
# Колпино                337 3866288.56380 3600000.00000
# Парголово              327 4488074.79817 4100000.00000
# Гатчина                307 3488336.67752 3100000.00000
# Выборг                 237 3250983.12236 2897000.00000

# %%
max_by_median_idx = price_by_loc['median'].idxmax()
min_by_median_idx = price_by_loc['median'].idxmin()

# выведем нас. пункт с самой высокой средней стоимостью
print(f'Населенный пункт с самой высокой средней стоимостью жилья: ' +
      f'{max_by_median_idx}')
# выведем нас. пункт с самой низкой средней стоимостью
print(f'Населенный пункт с самой низкой средней стоимостью жилья: ' +
      f'{min_by_median_idx}')

data.query('locality_clean_name in [@max_by_median_idx, @min_by_median_idx]').head()
# Out:
# Населенный пункт с самой высокой средней стоимостью жилья: Хязельки
# Населенный пункт с самой низкой средней стоимостью жилья: Вахнова Кара
#        total_images     last_price  price_per_meter  total_area  \
# 7399              3 11000000.00000      47826.08696   230.00000
# 16219            14   450000.00000      11688.31169    38.50000
#
#       first_day_exposition  exp_week_day  exp_month  exp_year  rooms  \
# 7399            2018-03-01             3          3      2018      5
# 16219           2018-07-11             2          7      2018      2
#
#        ceiling_height  floors_total  living_area  floor floor_type  studio  \
# 7399          2.50000       2.00000          NaN      2  Последний   False
# 16219         2.65000       2.00000          NaN      1     Первый   False
#
#        open_plan  kitchen_area  balcony         locality_name  \
# 7399       False           NaN  0.00000      деревня Хязельки
# 16219      False           NaN  0.00000  деревня Вахнова Кара
#
# ...

# %%
# сохраним 10 верхних значений из price_by_loc по количеству объявлений
top10_by_loc = price_by_loc.sort_values(by='count', ascending=False)[:10].reset_index()
# сохраним среднюю стоимость по этим 10 нас. пунктам
top10_by_loc_median = (data
                       .query('locality_clean_name in @top10_by_loc.locality_clean_name')['last_price']
                       .median()
                       )
('Средняя стоимость жилья в 10 нас. пунктах с наибольшем числом объявлений: ' +
 f'{round(top10_by_loc_median, 2):,} руб.'
 )
# Out:
# 'Средняя стоимость жилья в 10 нас. пунктах с наибольшем числом объявлений: 5,000,000.0 руб.'

# %%
price_by_loc_plot = sns.barplot(
    x='locality_clean_name',
    y='median',
    data=top10_by_loc)

# Повернем наименование нас пункта на 45 градусов
for item in price_by_loc_plot.get_xticklabels():
    item.set_rotation(45)

plt.title('Стоимость квартиры по нас. пунктам')
plt.show;

# %% [markdown]
# *Вывод:* мы отобрали и проанализировали стоимость квартир для 10 нас. пунктов с наибольшим количеством объявлений. В результате получилось, что средняя стоимость жилья в этих нас. пунктах равна 5 млн. руб. При этом по столбчатой диаграмме видно, что такая средняя цена продиктована  большим количеством объявлений в Санкт-Петербурге, для которого средняя стоимость жилья составляет 5.4 млн. руб. Также высокая средняя стоимость наблюдается в г. Пушкино - около 5.2 млн. руб. В оставшихся же городах средняя стоимость колеблется в районе 3-4 млн. руб.
# Максимальная и минимальная средняя стоимость жилья находится в Хязельках и Вахновой Каре соответственно. Но это связано исключительно с единственными объявлениями в этих нас. пунктах.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Если вдруг тебе понравилась тема визуализации, рекомендую посмотреть на библиотеку `plotly`.
# </div>

# %% [markdown]
# ### Оценка стоимости по расположению квартиры

# %% [markdown]
# **Построим сводную таблицу для Санкт-Петербурга по удаленности от центра**

# %%
spb_price_by_dist = (data
                     .query('locality_clean_name == "Санкт-Петербург"')
                     .pivot_table(index='city_center_dist_km',
                                  values='last_price',
                                  aggfunc='median'
                                  )
                     )

spb_price_by_dist.plot(kind='bar', figsize=(15, 5));
plt.title('Стоимость квартиры по удаленности от центра')
plt.show;

# %%
sns.regplot(x=spb_price_by_dist.index,
            y=spb_price_by_dist['last_price']);
plt.title('Стоимость квартиры по удаленности от центра')
plt.show;

# %%
data.query('locality_clean_name == "Санкт-Петербург" and city_center_dist_km == 27')
# Out:
#       total_images     last_price  price_per_meter  total_area  \
# 748             13 14350000.00000     193918.91892    74.00000
# 5961             6  2250000.00000      70312.50000    32.00000
#
#      first_day_exposition  exp_week_day  exp_month  exp_year  rooms  \
# 748            2017-11-28             1         11      2017      2
# 5961           2018-02-27             1          2      2018      1
#
#       ceiling_height  floors_total  living_area  floor floor_type  studio  \
# 748          3.13000       5.00000     30.00000      3     Другой   False
# 5961         2.65000       2.00000     16.50000      2  Последний   False
#
#       open_plan  kitchen_area  balcony    locality_name locality_clean_name  \
# 748       False      25.00000  0.00000  Санкт-Петербург     Санкт-Петербург
# 5961      False       7.00000  0.00000  Санкт-Петербург     Санкт-Петербург
#
#       airports_nearest  city_center_dist  city_center_dist_km  \
# ...

# %% [markdown]
# *Вывод:* Мы видим обратную зависимость стоимости на жилье от расстояния до центра города - чем дальше от центра, тем дешевле жилье. Жилье в пределах двух километров в среднем стоит больше 9.5 млн. руб.
# Ранее мы посчитали, что средняя стоимость в СПб равна  5 400 000 руб., эта стоимость соответствует средней стоимости в 9-16 км от центра.
# Мы видим всплеск цены на 27м километре, но это связано с малым количеством наблюдений - всего 2 объявления - и высокой стоимостью одного  из объектов. Интересно, продалась ли эта квартира в 74 метра за 14 млн?

# %% [markdown]
# ### История стоимости на квартиры в Санкт-Петербурге

# %% [markdown]
# **Построим сводную таблицу для Санкт-Петербурга по удаленности от центра**

# %%
# Группируем данные по году и месяцу
median_price_by_month = (data.query('locality_clean_name == "Санкт-Петербург"')
                         .groupby(['exp_year',
                                   'exp_month']
                                 )['last_price']
                         .median()
                         .reset_index()
                        )
# Добавляем столбец с единицей для дня
median_price_by_month['exp_day'] = 1
# Переименуем столбцы
median_price_by_month.columns = ['year', 'month', 'median_price', 'day']

# Добавим стобец с датой
median_price_by_month['month_year'] = (pd.
                                       to_datetime(
                                           median_price_by_month[['year',
                                                                  'month',
                                                                  'day']]
                                       )
                                       )

# Удаляем вспомогательные колонки
median_price_by_month = (median_price_by_month
                         .drop(columns=['year',
                                        'month',
                                        'day'
                                       ]
                              )
                        )

# Удаляем выброс в первом месяце
median_price_by_month = (median_price_by_month
                         .query('median_price < 7000000')
                        )

# Строим график
median_price_by_month.plot('month_year',
                           'median_price',
                           linestyle='-',
                           marker='o',
                           figsize=(15, 5),
                           grid=True
                          );
plt.title('Средняя стоимость за время наблюдения')

plt.show;

# %% [markdown]
# *Вывод:* за рассматриваемый период с начала 2015 г. по середину 2017 г. мы видим, что сначала средняя стоимость квартир в С-Петербурге падала. Пик падения пришелся на август 2016 г. После это цены пошли в сторону роста.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для анализа архива объявлений о продаже жилья в Ленинградской области была проведена предобработка исходных данных, предоставленных Отделом Данных. Предобработка включала в себя:
# * Заполнение пропущенных данных
# * Поиск и удаление дубликатов
# * Исправление аномальных значений
# * Категоризация данных
# ***
# Для целей дальнейшего анализа были рассчитаны дополнительные атрибуты: цена квадратного метра, тип этажа и т.д.
# ***
# Основной анализ показал, что:
# 1. В основном на рынке жилья присутствуют квартиры общей площадью до 100 м². Данная площадь приходится почти на 95% продаваемого жилья.
# 2. Существует сильная прямая зависимость между общей площадью квартиры и жилой площадью. Также есть прямая связь между общей площадью и площадью кухни, но уже не так сильна. Графики показывают, что есть логичный предельный размер кухни - около 40 м².
# 3. 51% квартир стоит от 2 до 5 млн. руб.
# 4. 95% квартир имеют от 1 до 3 комнат. Однокомнатных и двухкомнатных немного больше  - около 8000 шт. каждого типа. Трехкомнатных - 5500 шт.
# 5. Большинство квартир находятся не выше 5го этажа. Это косвенно говорит о большом количестве хрущевок. Это предположение подтверждается гистограммой высотности зданий. Локальные пики соответствуют 5, 9, 16 и 25 этажным домам.
# 6. Распределение объявлений СПб и области - 68% и 32%. Бóльшая часть квартир находится на расстоянии 5-15 км от центра Санкт-Петербурга. Это объясняется тем, что на этом расстоянии находится большинство спальных районов.
# 7. 85% объявления были поданы в будние дни. Самыми активными месяцами для публикаций являются февраль - апрель. Летом, а также в декабре и январе объем поданых объявлений резко уменьшается.
# 8. В среднем объявление о продаже квартиры висит на сайте 94 дня.
# 9. Самым значимым фактором, влияющим на стоимость жилья является общая площадь недвижимости. Здесь коэффициент корреляции максимальный и равен 0,77.
# 10. Аналогично стоимость связана с жилой площадью и площадью кухни. Это очевидно связано с сильной связью между общей площадью и ее составляющими.
# 11. Чем больше комнат, тем выше стоимость квартиры. Это утвержддение так же связано с тем, что количество комнат прямо связано с общей площадью.
# 12. Этаж влияет на стоимость квартиры. За последний этаж в среднем предлагают 12% дисконта, за первый  - 18%.
# 13. А вот со временем публикации стоимость квартир никак не связана. Здесь все распределено довольно ровно, коэффициент корреляции близок к нулю.
# 14. Самые высокие средние цены на жилье относятся к г. Санкт-Петербургу и г. Пушкино - 5 300 000 руб. В целом по выборке средняя цена квартиры - 5 000 000 руб.
# 15. Чем дальше от центра города, тем дешевле жилье. Жилье в пределах двух километров в среднем стоит больше 9.5 млн. руб. Средняя стоимость в СПб соответствует средней стоимости в 9-16 км от центра - там расположены спальные районы.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
# **[общий комментарий]** Ячейки **markdown** в том числе мы можем использовать как дополнительный способ стилизации нашего проекта. Оставил ниже ссылку, с примерами стилизации.
#
# https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера: ✅</b>
#
#
# Возвращаю проект обратно, чтобы убедиться что все мои комментарии понятны и внести правки в проект.
#
# Если вдруг у тебя возникнут какие-то вопросы, то я с радостью отвечу на них 😊
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: ℹ️</b> Спасибо еще раз за комменты, это было полезно!</div>
